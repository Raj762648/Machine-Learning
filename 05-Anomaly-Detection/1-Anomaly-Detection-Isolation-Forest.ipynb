# %% [markdown]
# ## Isolation Forest Anomaly Detection

# %%
import pandas as pd
df=pd.read_csv('../Data/anomaly_2d_blobs.csv')
df.head()
# Out:
#          x1        x2  label
# 0  3.227161  4.580209      0
# 1  3.988568  3.602294      0
# 2  4.015153  2.324064      0
# 3  3.441041  3.773126      0
# 4  0.410501 -0.161045      0

# %%
import matplotlib.pyplot as plt
plt.scatter(df.iloc[:,0], df.iloc[:,1])
plt.show()

# %%
from sklearn.ensemble import IsolationForest
clf = IsolationForest(contamination=0.2)
clf.fit(df)
predictions = clf.predict(df)

# %%
import numpy as np
index = np.where(predictions < 0)
index
# Out:
# (array([   0,    8,    9,   15,   19,   22,   31,   33,   36,   42,   50,
#           52,   57,   58,   59,   62,   76,   81,   83,   92,   93,   94,
#          108,  115,  116,  117,  119,  121,  123,  125,  128,  129,  133,
#          135,  136,  139,  145,  146,  149,  161,  163,  171,  172,  173,
#          191,  192,  194,  195,  199,  205,  206,  211,  214,  223,  227,
#          234,  236,  251,  253,  254,  256,  259,  263,  268,  269,  276,
#          296,  299,  309,  315,  320,  321,  325,  327,  353,  356,  359,
#          371,  373,  381,  385,  387,  392,  407,  410,  417,  423,  424,
#          433,  434,  436,  439,  440,  455,  471,  472,  477,  481,  482,
#          483,  487,  491,  500,  502,  516,  527,  533,  535,  552,  557,
#          559,  567,  580,  581,  582,  585,  587,  588,  592,  594,  597,
#          598,  603,  608,  610,  619,  628,  639,  640,  649,  653,  659,
#          661,  662,  674,  675,  678,  680,  681,  683,  690,  691,  692,
#          696,  706,  724,  729,  736,  738,  739,  741,  742,  750,  766,
#          767,  773,  774,  775,  776,  778,  779,  780,  782,  785,  790,
#          791,  805,  806,  807,  811,  814,  816,  825,  829,  834,  849,
#          851,  859,  861,  865,  869,  871,  883,  889,  891,  893,  902,
#          917,  927,  929,  931,  932,  933,  934,  937,  942,  943,  952,
#          955,  957,  963,  977,  978,  981,  985,  996, 1016, 1017, 1018,
#         1019, 1020, 1021, 1032, 1034, 1036, 1037, 1053, 1055, 1058, 1060,
#         1065, 1069, 1073, 1079, 1080, 1083, 1086, 1088, 1094, 1095, 1111,
#         1112, 1119, 1121, 1132, 1135, 1146, 1149, 1162, 1171, 1172, 1206,
#         1210, 1212, 1216, 1218, 1231, 1235, 1236, 1244, 1247, 1250, 1259,
#         1265, 1270]),)

# %%
x=df.values

# %%
index = np.where(predictions < 0)
plt.scatter(df.iloc[:,0], df.iloc[:,1])
plt.scatter(x[index,0], x[index,1], edgecolors="r")
plt.show()
